# %% [markdown]
# # ARIMA

# %%
from statsmodels.tsa.arima_model import ARIMA
import matplotlib.pyplot as plt

def predict(data, p, d, q): # build model, predict 3 months
    result = ARIMA(data,order = (p, d, q)).fit()
    print(result.summary())
    if d == 0:
        p  = result.predict( '2020-03-20', '2020-07-01', dynamic=True)
    else:
        p  = result.predict( '2020-03-20', '2020-07-01', dynamic=True, typ='levels')
    df_p = pd.DataFrame(p)
    forcast = pd.concat([data,df_p],axis=1,keys=['original', 'predicted'])
    plt.figure()
    plt.plot(forcast)
    plt.title('Actual vs Predict')
    plt.show()

# %%
def get_best_param(data, pdq_list):
    best_aic = np.inf
    best_pdq = None
    tmp_model = None
    best_mdl = None
    for param in pdq_list:
        try:
            tmp_mdl = ARIMA(data,order = param)
            res = tmp_mdl.fit()
            if res.aic < best_aic:
                best_aic = res.aic
                best_pdq = param
        except:
             continue
    return best_aic, best_pdq

# %% [markdown]
# ## Read File

# %%
import os

files_path = 'csse_covid_19_time_series'
os.listdir(files_path)
# Out:
# ['.gitignore',
#  'Errata.csv',
#  'README.md',
#  'time_series_covid19_confirmed_global.csv',
#  'time_series_covid19_confirmed_US.csv',
#  'time_series_covid19_deaths_global.csv',
#  'time_series_covid19_deaths_US.csv',
#  'time_series_covid19_recovered_global.csv']

# %%
import pandas as pd

data = pd.read_csv('csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/20/20  4/21/20  4/22/20  4/23/20  \
# 0        0        0        0  ...     1026     1092     1176     1279
# 1        0        0        0  ...      584      609      634      663
# 2        0        0        0  ...     2718     2811     2910     3007
# 3        0        0        0  ...      717      717      723      723
# 4        0        0        0  ...       24       24       25       25
#
#    4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# ...

# %% [markdown]
# ## China

# %%
country = 'China'

# %%
china_data_raw = data[data["Country/Region"] == country]

# %%
china_data = pd.DataFrame(china_data_raw[china_data_raw.columns[4:]].sum(),columns=[country + " Confirmed"])
china_data.index = pd.to_datetime(china_data.index)
china_data.head()
# Out:
#             China Confirmed
# 2020-01-22              548
# 2020-01-23              643
# 2020-01-24              920
# 2020-01-25             1406
# 2020-01-26             2075

# %%
china_data.diff()['2020-02-10':'2020-02-20']
# Out:
#             China Confirmed
# 2020-02-10           2525.0
# 2020-02-11           2032.0
# 2020-02-12            373.0
# 2020-02-13          15136.0
# 2020-02-14           6463.0
# 2020-02-15           2055.0
# 2020-02-16           2100.0
# 2020-02-17           1921.0
# 2020-02-18           1777.0
# 2020-02-19            408.0
# 2020-02-20            458.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns #plot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller as ADF
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.arima_model import ARIMA
# %matplotlib inline 

# %pylab inline

pylab.rcParams['figure.figsize'] = (10, 6)   # set image size
sns.set(color_codes=True) # seaborn set background

# timing diagram
china_data.diff().plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
china_data = china_data.diff()[1:]

# %%
plot_acf(china_data).show()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
plot_pacf(china_data).show()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
ADF(china_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-e6e9477e3d12> in <module>
# ----> 1 ADF(china_data)
#
# D:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     234                          'deterministic regressors')
#     235     xdiff = np.diff(x)
# --> 236     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
#     237     nobs = xdall.shape[0]
#     238
#
# D:\Anaconda\lib\site-packages\statsmodels\tsa\tsatools.py in lagmat(x, maxlag, trim, original, use_pandas)
#     402     if xa.ndim == 1:
#     403         xa = xa[:, None]
# --> 404     nobs, nvar = xa.shape
#     405     if original in ['ex', 'sep']:
#     406         dropidx = nvar
#
# ValueError: too many values to unpack (expected 2)

# %%
import itertools
p = d = q = range(0, 15)
pdq = list(itertools.product(p, d, q))

best_aic, best_pdq = get_best_param(china_data, pdq)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ...

# %%
best_aic, best_pdq
# Out:
# (1711.2818766804612, (0, 2, 1))

# %%
predict(china_data, 0, 2, 1)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:     D2.China Confirmed   No. Observations:                   96
# Model:                 ARIMA(0, 2, 1)   Log Likelihood                -862.823
# Method:                       css-mle   S.D. of innovations           1891.209
# Date:                Sun, 10 May 2020   AIC                           1731.645
# Time:                        21:20:32   BIC                           1739.339
# Sample:                    01-25-2020   HQIC                          1734.755
#                          - 04-29-2020
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -1.0329      6.858     -0.151      0.881     -14.474      12.408
# ma.L1.D2.China Confirmed    -1.0000      0.026    -38.241      0.000      -1.051      -0.949
# ...

# %% [markdown]
# ## USA

# %%
country = "US"

# %%
us_data_raw = data[data["Country/Region"] == country]

# %%
us_data = pd.DataFrame(us_data_raw[us_data_raw.columns[4:]].sum(),columns=[country + " Confirmed"])
us_data.index = pd.to_datetime(us_data.index)
us_data.head()
# Out:
#             US Confirmed
# 2020-01-22             1
# 2020-01-23             1
# 2020-01-24             2
# 2020-01-25             2
# 2020-01-26             5

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns     #seaborn画出的图更好看，且代码更简单，缺点是可塑性差
from statsmodels.graphics.tsaplots import plot_acf  #自相关图
from statsmodels.tsa.stattools import adfuller as ADF  #平稳性检测
from statsmodels.graphics.tsaplots import plot_pacf    #偏自相关图
from statsmodels.stats.diagnostic import acorr_ljungbox    #白噪声检验
from statsmodels.tsa.arima_model import ARIMA
#seaborn 是建立在matplotlib之上的
# %matplotlib inline 

# %pylab inline

#jupyter中文显示是方框，加入下面两行即可显示中文，若嫌麻烦，也可去网上搜索如何永久显示中文
plt.rcParams['font.sans-serif'] = ['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False #用来正常显示负号
pylab.rcParams['figure.figsize'] = (10, 6)   #设置输出图片大小
sns.set(color_codes=True) #seaborn设置背景

#读取数据，指定日期列为指标，Pandas自动将“日期”列识别为Datetime格式
#data = pd.read_excel('arima_data.xls', index_col = u'日期')

#时序图
us_data.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
us_data.diff().plot()

# %%
us_data = us_data.diff()['2020-03-01':]

# %%
plot_acf(us_data).show()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
plot_pacf(us_data).show()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
from statsmodels.stats.diagnostic import unitroot_adf

unitroot_adf(us_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-6a57782ca40c> in <module>
#       1 from statsmodels.stats.diagnostic import unitroot_adf
#       2
# ----> 3 unitroot_adf(us_data)
#
# D:\Anaconda\lib\site-packages\statsmodels\sandbox\stats\diagnostic.py in unitroot_adf(x, maxlag, trendorder, autolag, store)
#      41 def unitroot_adf(x, maxlag=None, trendorder=0, autolag='AIC', store=False):
#      42     return adfuller(x, maxlag=maxlag, regression=trendorder, autolag=autolag,
# ---> 43                     store=store, regresults=False)
#      44
#      45
#
# D:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     234                          'deterministic regressors')
#     235     xdiff = np.diff(x)
# --> 236     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
# ...

# %%
import itertools
p = d = q = range(0, 15)
pdq = list(itertools.product(p, d, q))

best_aic, best_pdq = get_best_param(us_data, pdq)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ...

# %%
best_pdq, best_aic
# Out:
# ((2, 2, 3), 1070.273074374564)

# %%
predict(us_data, 2, 2, 3)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:        D2.US Confirmed   No. Observations:                   58
# Model:                 ARIMA(2, 2, 3)   Log Likelihood                -528.137
# Method:                       css-mle   S.D. of innovations           2021.984
# Date:                Sun, 10 May 2020   AIC                           1070.273
# Time:                        20:35:08   BIC                           1084.696
# Sample:                    03-03-2020   HQIC                          1075.891
#                          - 04-29-2020
# ...

# %% [markdown]
# ## NY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('csse_covid_19_time_series/time_series_covid19_confirmed_us.csv')
data.head()
# Out:
#      UID iso2 iso3  code3  FIPS Admin2            Province_State  \
# 0   16.0   AS  ASM     16  60.0    NaN            American Samoa
# 1  316.0   GU  GUM    316  66.0    NaN                      Guam
# 2  580.0   MP  MNP    580  69.0    NaN  Northern Mariana Islands
# 3  630.0   PR  PRI    630  72.0    NaN               Puerto Rico
# 4  850.0   VI  VIR    850  78.0    NaN            Virgin Islands
#
#   Country_Region      Lat     Long_  ... 4/20/20  4/21/20  4/22/20  4/23/20  \
# 0             US -14.2710 -170.1320  ...       0        0        0        0
# 1             US  13.4443  144.7937  ...     136      136      136      139
# 2             US  15.0979  145.6739  ...      14       14       14       14
# 3             US  18.2208  -66.5901  ...    1252     1298     1252     1416
# 4             US  18.3358  -64.8963  ...      53       53       54       54
#
#    4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# 0        0        0        0        0        0        0
# ...

# %%
ny_data_raw = data[data['Province_State'] == 'New York']
ny_data_raw.head()
# Out:
#              UID iso2 iso3  code3     FIPS       Admin2 Province_State  \
# 1833  84036001.0   US  USA    840  36001.0       Albany       New York
# 1834  84036003.0   US  USA    840  36003.0     Allegany       New York
# 1835  84036005.0   US  USA    840  36005.0        Bronx       New York
# 1836  84036007.0   US  USA    840  36007.0       Broome       New York
# 1837  84036009.0   US  USA    840  36009.0  Cattaraugus       New York
#
#      Country_Region        Lat      Long_  ... 4/20/20  4/21/20  4/22/20  \
# 1833             US  42.600603 -73.977239  ...     687      704      737
# 1834             US  42.257484 -78.027505  ...      30       30       30
# 1835             US  40.852093 -73.862828  ...       0        0        0
# 1836             US  42.159032 -75.813261  ...     199      205      219
# 1837             US  42.247782 -78.679231  ...      34       35       37
#
#       4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20
# ...

# %%
ny_data = pd.DataFrame(ny_data_raw[ny_data_raw.columns[11:]].sum(),columns=["Confirmed"])
ny_data.index = pd.to_datetime(ny_data.index)
ny_data['2020-03-01':].head()
# Out:
#             Confirmed
# 2020-03-01          0
# 2020-03-02          1
# 2020-03-03          2
# 2020-03-04         11
# 2020-03-05         23

# %%
import seaborn as sns #plot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller as ADF
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.arima_model import ARIMA
# %matplotlib inline 

# %pylab inline

pylab.rcParams['figure.figsize'] = (10, 6)   # set image size
sns.set(color_codes=True) # seaborn set background

# timing diagram
ny_data.diff().plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ny_data = ny_data.diff()['2020-03-01':]

# %%
ny_data.plot()

# %%
plot_acf(ny_data).show()
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
plot_pacf(ny_data).show()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   """Entry point for launching an IPython kernel.

# %%
from statsmodels.stats.diagnostic import unitroot_adf

unitroot_adf(ny_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-11b38b7f1f63> in <module>
#       1 from statsmodels.stats.diagnostic import unitroot_adf
#       2
# ----> 3 unitroot_adf(ny_data)
#
# D:\Anaconda\lib\site-packages\statsmodels\sandbox\stats\diagnostic.py in unitroot_adf(x, maxlag, trendorder, autolag, store)
#      41 def unitroot_adf(x, maxlag=None, trendorder=0, autolag='AIC', store=False):
#      42     return adfuller(x, maxlag=maxlag, regression=trendorder, autolag=autolag,
# ---> 43                     store=store, regresults=False)
#      44
#      45
#
# D:\Anaconda\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     234                          'deterministic regressors')
#     235     xdiff = np.diff(x)
# --> 236     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
# ...

# %%
import itertools
p = q = range(0, 15)
d = range(0, 3)
pdq = list(itertools.product(p, d, q))

best_aic, best_pdq = get_best_param(ny_data, pdq)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# ...

# %%
best_aic, best_pdq
# Out:
# (1010.8857596777971, (4, 2, 1))

# %%
predict(ny_data, 4, 2, 1)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D2.Confirmed   No. Observations:                   58
# Model:                 ARIMA(4, 2, 1)   Log Likelihood                -498.443
# Method:                       css-mle   S.D. of innovations           1270.250
# Date:                Sun, 10 May 2020   AIC                           1010.886
# Time:                        21:12:54   BIC                           1025.309
# Sample:                    03-03-2020   HQIC                          1016.504
#                          - 04-29-2020
# ...

# %%
predict(ny_data, 11,0,0)
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                               ARMA Model Results
# ...
# Dep. Variable:              Confirmed   No. Observations:                   60
# Model:                    ARMA(11, 0)   Log Likelihood                -507.886
# Method:                       css-mle   S.D. of innovations           1099.320
# Date:                Sun, 10 May 2020   AIC                           1041.771
# Time:                        20:25:29   BIC                           1068.998
# Sample:                    03-01-2020   HQIC                          1052.421
#                          - 04-29-2020
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
